# %% [markdown]
# Part 1: Step 1:
#
# Code Description: The code gets the html file of the website and parse it into a data frame and then rename some columns.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re 
import numpy as np
from datetime import datetime  
from datetime import timedelta 
from math import exp
import math

# %%
page = requests.get('https://www.spaceweatherlive.com/en/solar-activity/top-50-solar-flares')

# %%
soup = BeautifulSoup(page.text, 'html.parser')

# %%
table = soup.find_all('table')[0] 
df = pd.read_html(str(table))[0]

# %%
df = df.rename(columns={"Unnamed: 0": "rank", "Unnamed: 1": "flare_classification", "Unnamed: 2": "date", "Region": "flare_region", 
                   "Start": "start_time", "Maximum": "maximum_time", "End": "end_time", "Unnamed: 7": "movie"})
df.index += 1

# %%
df
# Out:
#     rank flare_classification        date  flare_region start_time  \
# 1      1                 X28+  2003/11/04           486      19:29
# 2      2                 X20+  2001/04/02          9393      21:32
# 3      3               X17.2+  2003/10/28           486      09:51
# 4      4                 X17+  2005/09/07           808      17:17
# 5      5                X14.4  2001/04/15          9415      13:19
# 6      6                  X10  2003/10/29           486      20:37
# 7      7                 X9.4  1997/11/06          8100      11:49
# 8      8                 X9.3  2017/09/06          2673      11:53
# 9      9                   X9  2006/12/05           930      10:18
# 10    10                 X8.3  2003/11/02           486      17:03
# 11    11                 X8.2  2017/09/10          2673      15:35
# 12    12                 X7.1  2005/01/20           720      06:36
# 13    13                 X6.9  2011/08/09          1263      07:48
# 14    14                 X6.5  2006/12/06           930      18:29
# 15    15                 X6.2  2005/09/09           808      19:13
# 16    16                 X6.2  2001/12/13          9733      14:20
# 17    17                 X5.7  2000/07/14          9077      10:03
# 18    18                 X5.6  2001/04/06          9415      19:10
# 19    19                 X5.4  2012/03/07          1429      00:02
# 20    20                 X5.4  2005/09/08           808      20:52
# 21    21                 X5.4  2003/10/23           486      08:19
# 22    22                 X5.3  2001/08/25          9591      16:23
# 23    23                 X4.9  2014/02/25          1990      00:39
# 24    24                 X4.9  1998/08/18          8307      22:10
# 25    25                 X4.8  2002/07/23            39      00:18
# 26    26                   X4  2000/11/26          9236      16:34
# 27    27                 X3.9  2003/11/03           488      09:43
# 28    28                 X3.9  1998/08/19          8307      21:35
# 29    29                 X3.8  2005/01/17           720      06:59
# 30    30                 X3.7  1998/11/22          8384      06:30
# 31    31                 X3.6  2005/09/09           808      09:42
# 32    32                 X3.6  2004/07/16           649      13:49
# 33    33                 X3.6  2003/05/28           365      00:17
# 34    34                 X3.4  2006/12/13           930      02:14
# 35    35                 X3.4  2001/12/28          9767      20:02
# 36    36                 X3.3  2013/11/05          1890      22:07
# 37    37                 X3.3  2002/07/20            39      21:04
# 38    38                 X3.3  1998/11/28          8395      04:54
# 39    39                 X3.2  2013/05/14          1748      00:00
# 40    40                 X3.1  2014/10/24          2192      21:07
# 41    41                 X3.1  2002/08/24            69      00:49
# 42    42                   X3  2002/07/15            30      19:59
# 43    43                 X2.8  2013/05/13          1748      15:48
# 44    44                 X2.8  2001/12/11          9733      07:58
# 45    45                 X2.8  1998/08/18          8307      08:14
# 46    46                 X2.7  2015/05/05          2339      22:05
# 47    47                 X2.7  2003/11/03           488      01:09
# 48    48                 X2.7  1998/05/06          8210      07:58
# 49    49                 X2.6  2005/01/15           720      22:25
# 50    50                 X2.6  2001/09/24          9632      09:32
#
#    maximum_time end_time              movie
# 1         19:53    20:06  MovieView archive
# 2         21:51    22:03  MovieView archive
# 3         11:10    11:24  MovieView archive
# 4         17:40    18:03  MovieView archive
# 5         13:50    13:55  MovieView archive
# 6         20:49    21:01  MovieView archive
# 7         11:55    12:01  MovieView archive
# 8         12:02    12:10  MovieView archive
# 9         10:35    10:45  MovieView archive
# 10        17:25    17:39  MovieView archive
# 11        16:06    16:31  MovieView archive
# 12        07:01    07:26  MovieView archive
# 13        08:05    08:08  MovieView archive
# 14        18:47    19:00  MovieView archive
# 15        20:04    20:36  MovieView archive
# 16        14:30    14:35  MovieView archive
# 17        10:24    10:43  MovieView archive
# 18        19:21    19:31  MovieView archive
# 19        00:24    00:40  MovieView archive
# 20        21:06    21:17  MovieView archive
# 21        08:35    08:49  MovieView archive
# 22        16:45    17:04  MovieView archive
# 23        00:49    01:03  MovieView archive
# 24        22:19    22:28       View archive
# 25        00:35    00:47  MovieView archive
# 26        16:48    16:56  MovieView archive
# 27        09:55    10:19  MovieView archive
# 28        21:45    21:50       View archive
# 29        09:52    10:07  MovieView archive
# 30        06:42    06:49  MovieView archive
# 31        09:59    10:08  MovieView archive
# 32        13:55    14:01  MovieView archive
# 33        00:27    00:39  MovieView archive
# 34        02:40    02:57  MovieView archive
# 35        20:45    21:32  MovieView archive
# 36        22:12    22:15  MovieView archive
# 37        21:30    21:54  MovieView archive
# 38        05:52    06:13  MovieView archive
# 39        01:11    01:20  MovieView archive
# 40        21:41    22:13  MovieView archive
# 41        01:12    01:31  MovieView archive
# 42        20:08    20:14  MovieView archive
# 43        16:05    16:16  MovieView archive
# 44        08:08    08:14  MovieView archive
# 45        08:24    08:32       View archive
# 46        22:11    22:15  MovieView archive
# 47        01:30    01:45  MovieView archive
# 48        08:09    08:20  MovieView archive
# 49        23:02    23:31  MovieView archive
# 50        10:38    11:09  MovieView archive

# %% [markdown]
# Step 2:
#
# Code Description: The code use df operations to combine date and time. Then it drops and renames some columns. Lastly, it convert the 3 columns into datetime type.

# %%
df["start_time"] = df["date"] + " " + df["start_time"]

# %%
df["maximum_time"] = df["date"] + " " + df["maximum_time"]

# %%
df["end_time"] = df["date"] + " " + df["end_time"]

# %%
df = df.drop(columns=["movie", "date"])

# %%
df = df.rename(columns = {"start_time": "start_datetime", "maximum_time": "max_datetime", "end_time": "end_datetime"})

# %%
df['start_datetime']= pd.to_datetime(df['start_datetime']) 
df['max_datetime']= pd.to_datetime(df['max_datetime']) 
df['end_datetime']= pd.to_datetime(df['end_datetime'])

# %%
# change type
df.flare_classification = df.flare_classification.astype('string')

# %%
df
# Out:
#     rank flare_classification  flare_region      start_datetime  \
# 1      1                 X28+           486 2003-11-04 19:29:00
# 2      2                 X20+          9393 2001-04-02 21:32:00
# 3      3               X17.2+           486 2003-10-28 09:51:00
# 4      4                 X17+           808 2005-09-07 17:17:00
m = re.findall(r"(\d{4}/\d{2}/\d{2}) (\d{2}:\d{2}) (\d{2}/\d{2}) (\d{2}:\d{2}).+>(\d+)</a>.+>(\d+)</a>.*\s+(\w+|-{3,6})\s+(\w+|-{3,6})\s+(\w+\.\d?|-{3,6}).+(\d{2}/\d{2}|-{3,6}).+(\d{2}:\d{2}|-{3,6})\s+(\w+|-{3,6})\s+(&?g?t?;?\w+|-{3,6})\s+(?!\d{4}/\d{2}/\d{2}).+>(\d+|-{3,6})</a>.+>PHTX</(?!\d{4}/\d{2}/\d{2})", t)

# %%
tb = pd.DataFrame(m, columns =['start_date', 'start_time', 'end_date', 'end_time', 'start_frequency','end_frequency', 'flare_location', 'flare_region', 'flare_classification', 'cme_date', 'cme_time','cme_angle', 'cme_width', 'cme_speed'])

# %%
x = re.sub(r"(\d{4}/\d{2}/\d{2}) (\d{2}:\d{2}) (\d{2}/\d{2}) (\d{2}:\d{2}).+>(\d+)</a>.+>(\d+)</a>.*\s+(\w+|-{3,6})\s+(\w+|-{3,6})\s+(\w+\.\d?|-{3,6}).+(\d{2}/\d{2}|-{3,6}).+(\d{2}:\d{2}|-{3,6})\s+(\w+|-{3,6})\s+(&?g?t?;?\w+|-{3,6})\s+(?!\d{4}/\d{2}/\d{2}).+>(\d+|-{3,6})</a>.+>PHTX</(?!\d{4}/\d{2}/\d{2})","", t)

# %%
rem = re.findall(r"(\d{4}/\d{2}/\d{2}) (\d{2}:\d{2}) (\d{2}/\d{2}) (\d{2}:\d{2}).+>(\d+|\?+)</a>.+>(\d+|\?+)</a>.*\s+(\w+\??|-{3,6})\s+(\w+\??|-{3,6})\s+(\w+\.?\d?|-{3,6}).+(\d{2}/\d{2}|--/--).+(\d{2}:\d{2}|--:--)\s+(\w+|-{3,6})\s+(&?g?t?;?\w+|-{3,6})\s+.+(>\d+</a|-{3,6}).+<a href.+PHTX</a>(?!\d{4}/\d{2}/\d{2})", x)

# %%
y = re.sub(r"(\d{4}/\d{2}/\d{2}) (\d{2}:\d{2}) (\d{2}/\d{2}) (\d{2}:\d{2}).+>(\d+|\?+)</a>.+>(\d+|\?+)</a>.*\s+(\w+\??|-{3,6})\s+(\w+\??|-{3,6})\s+(\w+\.?\d?|-{3,6}).+(\d{2}/\d{2}|--/--).+(\d{2}:\d{2}|--:--)\s+(\w+|-{3,6})\s+(&?g?t?;?\w+|-{3,6})\s+.+(>\d+</a|-{3,6}).+<a href.+PHTX</a>(?!\d{4}/\d{2}/\d{2})", "", x)

# %%
rem2 = re.findall(r"(\d{4}/\d{2}/\d{2}) (\d{2}:\d{2}) (\d{2}/\d{2}) (\d{2}:\d{2})\s+(\d+|\?+)\s+(\d+|\?+)\s+(\w+\??|-{3,6})\s+(\w+|-{3,6})\s+(\w+\.?\d?|-{3,6}).+(\d{2}/\d{2}|--/--).+(\d{2}:\d{2}|--:--)\s+(\w+|-{3,6})\s+(&?g?t?;?\w+|-{3,6})\s+.+(>\d+</a|-{3,6}).+<a href.+PHTX</a>(?!\d{4}/\d{2}/\d{2})", y)

# %%
z = re.sub(r"(\d{4}/\d{2}/\d{2}) (\d{2}:\d{2}) (\d{2}/\d{2}) (\d{2}:\d{2})\s+(\d+|\?+)\s+(\d+|\?+)\s+(\w+\??|-{3,6})\s+(\w+|-{3,6})\s+(\w+\.?\d?|-{3,6}).+(\d{2}/\d{2}|--/--).+(\d{2}:\d{2}|--:--)\s+(\w+|-{3,6})\s+(&?g?t?;?\w+|-{3,6})\s+.+(>\d+</a|-{3,6}).+<a href.+PHTX</a>(?!\d{4}/\d{2}/\d{2})", "", y)

# %%
rem3 = re.findall(r"(\d{4}/\d{2}/\d{2}) (\d{2}:\d{2}) (\d{2}/\d{2}) (\d{2}:\d{2}).+>(\d+|\?+)</a>\s+(\d+|\?+)\s+(\w+\??|-.*-)\s*(\w+|-.*-)\s+(\w+\.?\d?|-.*-).+(\d{2}/\d{2}|-.*-).+(\d{2}:\d{2}|-.*-)\s+(\w+|-.*-)\s+(&?g?t?;?\w+|-.*-)\s+.+(>\d+</a|-.*-).+<a href.+PHTX</a>(?!\d{4}/\d{2}/\d{2})", z)

# %%
rem4 = re.findall(r"(\d{4}/\d{2}/\d{2}) (\d{2}:\d{2}) (\d{2}/\d{2}) (\d{2}:\d{2}).+>(\d+|\?+)</a>.+>(\d+|\?+)</a>.*\s+(\w+\??|-.*-)\s+(\w+\??|-.*-)\s*(\w+\.?\d?|-.*-).+(\d{2}/\d{2}|-.*-).+(\d{2}:\d{2}|-.*-)\s+(\w+|-.*-)\s+(&?g?t?;?\w+|-.*-)\s+.+>(\d+)</a.+<a href.+PHTX</a>(?!\d{4}/\d{2}/\d{2})", z)

# %%
tb1 = pd.DataFrame(rem, columns =['start_date', 'start_time', 'end_date', 'end_time', 'start_frequency','end_frequency', 'flare_location', 'flare_region', 'flare_classification', 'cme_date', 'cme_time','cme_angle', 'cme_width', 'cme_speed'])

# %%
tb2 = pd.DataFrame(rem2, columns =['start_date', 'start_time', 'end_date', 'end_time', 'start_frequency','end_frequency', 'flare_location', 'flare_region', 'flare_classification', 'cme_date', 'cme_time','cme_angle', 'cme_width', 'cme_speed'])

# %%
tb3 = pd.DataFrame(rem3, columns =['start_date', 'start_time', 'end_date', 'end_time', 'start_frequency','end_frequency', 'flare_location', 'flare_region', 'flare_classification', 'cme_date', 'cme_time','cme_angle', 'cme_width', 'cme_speed'])

# %%
tb4 = pd.DataFrame(rem4, columns =['start_date', 'start_time', 'end_date', 'end_time', 'start_frequency','end_frequency', 'flare_location', 'flare_region', 'flare_classification', 'cme_date', 'cme_time','cme_angle', 'cme_width', 'cme_speed'])

# %%
nasa = tb.append([tb1, tb2,tb3, tb4], ignore_index=True)

# %%
nasa.sort_values(by=['start_date'], inplace = True)
nasa = nasa.reset_index()

# %%
nasa.index += 1

# %%
nasa = nasa.drop(columns=["index"])

# %%
nasa
# Out:
#      start_date start_time end_date end_time start_frequency end_frequency  \
# 1    1997/04/01      14:00    04/01    14:15            8000          4000
# 2    1997/04/07      14:30    04/07    17:30           11000          1000
# 3    1997/05/12      05:15    05/14    16:00           12000            80
# 4    1997/05/21      20:20    05/21    22:00            5000           500
# 5    1997/09/23      21:53    09/23    22:16            6000          2000
# ..          ...        ...      ...      ...             ...           ...
# 514  2017/09/04      20:27    09/05    04:54           14000           210
# 515  2017/09/06      12:05    09/07    08:00           16000            70
# 516  2017/09/10      16:02    09/11    06:50           16000           150
# 517  2017/09/12      07:38    09/12    07:43           16000         13000
# 518  2017/09/17      11:45    09/17    12:35           16000           900
#
#     flare_location flare_region flare_classification cme_date cme_time  \
# 1           S25E16         8026                 M1.3    04/01    15:18
# 2           S28E19         8027                 C6.8    04/07    14:27
# 3           N21W08         8038                 C1.3    05/12    05:30
# 4           N05W12         8040                 M1.3    05/21    21:00
# 5           S29E25         8088                 C1.4    09/23    22:02
# ..             ...          ...                  ...      ...      ...
# 514         S10W12        12673                 M5.5    09/04    20:12
# 515         S08W33        12673                 X9.3    09/06    12:24
# 516         S09W92        -----                 X8.3    09/10    16:00
# 517         N08E48        12680                 C3.0    09/12    08:03
# 518        S08E170     --------                   --    09/17    12:00
#
#     cme_angle cme_width cme_speed
# 1          74        79       312
# 2        Halo       360       878
# 3        Halo       360       464
# 4         263       165       296
# 5         133       155       712
# ..        ...       ...       ...
# 514      Halo       360      1418
# 515      Halo       360      1571
# 516      Halo       360      3163
# 517       124        96       252
# 518      Halo       360      1385
#
# [518 rows x 14 columns]

# %% [markdown]
# Step 4:
#
# Code Description: The code first uses regex to replace missing values with NA. And then it combines the date and time columns into datetime columns. And it drops some columns and convert each column into their correct data type. (The code replaces 360h with 360 and increments the date with 24:00 by 1 day and replaces 24:00 with 00:00.

# %%
nasa = nasa.replace(regex={r'-{1,9}': np.nan})

# %%
nasa['halo'] = np.where(nasa['cme_angle']=='Halo', True, False)

# %%
nasa = nasa.replace(regex= {r'Halo': np.nan})

# %%
nasa['cme_width_limit'] = np.where(nasa['cme_width'].str.contains('&gt;'), True, False)

# %%
nasa = nasa.replace(regex = {r'&gt;': ''})

# %%
nasa["start_time"] = nasa["start_date"] + " " + nasa["start_time"]

# %%
nasa['end_time'] = nasa['start_date'].astype(str).str[:5] + nasa['end_date'] + " " + nasa['end_time']

# %%
nasa['cme_time'] = nasa['start_date'].astype(str).str[:5]+ nasa['cme_date'] + " " + nasa['cme_time']

# %%
nasa['start_time']= pd.to_datetime(nasa['start_time'])

# %%
nasa['help'] = np.where(nasa['end_time'].str.contains('24:00'), True, False)

# %%
nasa['end_time'] = nasa['end_time'].replace(regex={'24:00': '00:00'})

# %%
nasa['end_time']= pd.to_datetime(nasa['end_time'])

# %%
nasa['cme_time']= pd.to_datetime(nasa['cme_time'])

# %%
nasa['end_time']= np.where(nasa['help']== True, nasa['end_time'] + timedelta(days=1), nasa['end_time'])

# %%
nasa = nasa.rename(columns = {"start_time": "start_datetime", "end_time": "end_datetime", "cme_time": "cme_datetime"})

# %%
nasa = nasa.drop(columns=["start_date", "end_date", "cme_date", "help"])

# %%
nasa = nasa.replace(regex={r'\?{1,9}': np.nan})

# %%
nasa = nasa.replace(regex={r'>': ''})

# %%
nasa = nasa.replace(regex = {r'</a': ''})

# %%
nasa = nasa.replace(regex={r'BACK': np.nan})
nasa = nasa.replace(regex={r'Back': np.nan})
nasa = nasa.replace(regex={r'FILA': np.nan})
nasa = nasa.replace(regex={r'DSF': np.nan})

# %%
nasa = nasa.replace(regex={r'360h': '360'}) #no idea how to deal with the h

# %%
nasa.start_frequency = pd.to_numeric(nasa.start_frequency).astype('Int64')
nasa.end_frequency = pd.to_numeric(nasa.end_frequency).astype('Int64')
nasa.cme_angle = pd.to_numeric(nasa.cme_angle).astype('Int64')
nasa.cme_speed = pd.to_numeric(nasa.cme_speed).astype('Int64')
nasa.cme_width = pd.to_numeric(nasa.cme_width).astype('Int64')

# %%
nasa['flare_location'] = nasa['flare_location'].astype('string')
nasa.flare_region = nasa.flare_region.astype('string')
nasa.flare_classification = nasa.flare_classification.astype('string')

# %%
nasa
# Out:
#          start_datetime        end_datetime  start_frequency  end_frequency  \
# 1   1997-04-01 14:00:00 1997-04-01 14:15:00             8000           4000
# 2   1997-04-07 14:30:00 1997-04-07 17:30:00            11000           1000
# 3   1997-05-12 05:15:00 1997-05-14 16:00:00            12000             80
# 4   1997-05-21 20:20:00 1997-05-21 22:00:00             5000            500
# 5   1997-09-23 21:53:00 1997-09-23 22:16:00             6000           2000
# ..                  ...                 ...              ...            ...
# 514 2017-09-04 20:27:00 2017-09-05 04:54:00            14000            210
# 515 2017-09-06 12:05:00 2017-09-07 08:00:00            16000             70
# 516 2017-09-10 16:02:00 2017-09-11 06:50:00            16000            150
# 517 2017-09-12 07:38:00 2017-09-12 07:43:00            16000          13000
# 518 2017-09-17 11:45:00 2017-09-17 12:35:00            16000            900
#
#     flare_location flare_region flare_classification        cme_datetime  \
# 1           S25E16         8026                 M1.3 1997-04-01 15:18:00
# 2           S28E19         8027                 C6.8 1997-04-07 14:27:00
# 3           N21W08         8038                 C1.3 1997-05-12 05:30:00
# 4           N05W12         8040                 M1.3 1997-05-21 21:00:00
# 5           S29E25         8088                 C1.4 1997-09-23 22:02:00
# ..             ...          ...                  ...                 ...
# 514         S10W12        12673                 M5.5 2017-09-04 20:12:00
# 515         S08W33        12673                 X9.3 2017-09-06 12:24:00
# 516         S09W92         <NA>                 X8.3 2017-09-10 16:00:00
# 517         N08E48        12680                 C3.0 2017-09-12 08:03:00
# 518        S08E170         <NA>                 <NA> 2017-09-17 12:00:00
#
#      cme_angle  cme_width  cme_speed   halo  cme_width_limit
# 1           74         79        312  False            False
# 2         <NA>        360        878   True            False
# 3         <NA>        360        464   True            False
# 4          263        165        296  False            False
# 5          133        155        712  False            False
# ..         ...        ...        ...    ...              ...
# 514       <NA>        360       1418   True            False
# 515       <NA>        360       1571   True            False
# 516       <NA>        360       3163   True            False
# 517        124         96        252  False            False
# 518       <NA>        360       1385   True            False
#
# [518 rows x 13 columns]

# %% [markdown]
# Part 2: Question 1:
#
# Description: I can replicate most of the top 50 solar flare events. But several events on the spaceweather website are missing on the NASA website, which is why I can't get the same data as the spaceweather website. Generally, my code can replicate the SpaceWeatherLive data pretty well despite the missing data.

# %%
q1 = nasa[nasa['flare_classification'].notna()]

# %%
q1 = q1[q1['flare_classification'].str.match(r'X.+')]

# %%
q1['help'] = pd.to_numeric(q1["flare_classification"].str.split("X", n = 1, expand = True)[1])

# %%
q1.sort_values(by=['help', 'start_datetime'], inplace=True, ascending=[False,True])

# %%
q1 = q1.drop(columns=['help'])
top50 = q1.head(50).reset_index(drop=True)
top50.index += 1

# %%
top50
# Out:
#         start_datetime        end_datetime  start_frequency  end_frequency  \
# 1  2003-11-04 20:00:00 2003-11-05 00:00:00            10000            200
# 2  2001-04-02 22:05:00 2001-04-03 02:30:00            14000            250
# 3  2003-10-28 11:10:00 2003-10-30 00:00:00            14000             40
# 4  2001-04-15 14:05:00 2001-04-16 13:00:00            14000             40
# 5  2003-10-29 20:55:00 2003-10-30 00:00:00            11000            500
# 6  1997-11-06 12:20:00 1997-11-07 08:30:00            14000            100
# 7  2017-09-06 12:05:00 2017-09-07 08:00:00            16000             70
# 8  2006-12-05 10:50:00 2006-12-05 20:00:00            14000            250
# 9  2003-11-02 17:30:00 2003-11-03 01:00:00            12000            250
# 10 2017-09-10 16:02:00 2017-09-11 06:50:00            16000            150
# 11 2005-01-20 07:15:00 2005-01-20 16:30:00            14000             25
# 12 2011-08-09 08:20:00 2011-08-09 08:35:00            16000           4000
# 13 2006-12-06 19:00:00 2006-12-09 00:00:00            16000             30
# 14 2005-09-09 19:45:00 2005-09-09 22:00:00            10000             50
# 15 2000-07-14 10:30:00 2000-07-15 14:30:00            14000             80
# 16 2001-04-06 19:35:00 2001-04-07 01:50:00            14000            230
# 17 2012-03-07 01:00:00 2012-03-08 19:00:00            16000             30
# 18 2001-08-25 16:50:00 2001-08-25 23:00:00             8000            170
# 19 2014-02-25 00:56:00 2014-02-25 11:28:00            14000            100
# 20 2002-07-23 00:50:00 2002-07-23 04:00:00            11000            400
# 21 2000-11-26 17:00:00 2000-11-26 17:15:00            14000           7000
# 22 2003-11-03 10:00:00 2003-11-03 12:30:00             6000            400
# 23 2005-01-17 10:00:00 2005-01-17 10:35:00             6100           1500
# 24 2003-05-28 01:00:00 2003-05-29 00:30:00             1000            200
# 25 2001-12-28 20:35:00 2001-12-29 03:00:00            14000            350
# 26 2006-12-13 02:45:00 2006-12-13 10:40:00            12000            150
# 27 2002-07-20 21:30:00 2002-07-20 22:20:00            10000           2000
# 28 2013-05-14 01:16:00 2013-05-14 08:20:00            16000            240
# 29 2002-08-24 01:45:00 2002-08-24 03:25:00             5000            400
# 30 2013-05-13 16:15:00 2013-05-13 19:10:00            16000            300
# 31 1998-05-06 08:25:00 1998-05-06 08:35:00            14000           5000
# 32 2003-11-03 01:15:00 2003-11-03 01:25:00             3000           1500
# 33 2015-05-05 22:24:00 2015-05-05 23:14:00            14000            500
# 34 1997-11-27 13:30:00 1997-11-27 14:00:00            14000           7000
# 32         N10W83        10488                 X2.7 2003-11-03 01:59:00
# 33         N15E79        12339                 X2.7 2015-05-05 22:24:00
# 34         N17E63         8113                 X2.6 1997-11-27 13:56:00
# 35         S16E23         9632                 X2.6 2001-09-24 10:30:00
# 36         N15W05        10720                 X2.6 2005-01-15 23:06:00
# 37         N09W49        10696                 X2.5 2004-11-10 02:26:00
# 38         N20E18         9026                 X2.3 2000-06-06 15:54:00
# 39         N22W07         9236                 X2.3 2000-11-24 15:30:00
# 40         S23W09         9415                 X2.3 2001-04-10 05:30:00
# 41         S20W12        11158                 X2.2 2011-02-15 02:24:00
# 42         S14W33         8100                 X2.1 1997-11-04 06:10:00
# 43         S13E47        10808                 X2.1 2005-09-10 21:52:00
# 44         N14W18        11283                 X2.1 2011-09-06 23:05:00
# 45         S06E69        11882                 X2.1 2013-10-25 15:12:00
# 46         N20W05         9236                 X2.0 2000-11-24 05:30:00
# 47         S19W43         9415                 X2.0 2001-04-12 10:31:00
# 48         N09W17        10696                 X2.0 2004-11-07 16:54:00
# 49         N15W25        10720                 X2.0 2005-01-17 09:30:00
# 50         N20W23         9236                 X1.9 2000-11-25 19:31:00
#
#     cme_angle  cme_width  cme_speed   halo  cme_width_limit
# 1        <NA>        360       2657   True            False
# 2         261        244       2505  False            False
# 3        <NA>        360       2459   True            False
# 4         245        167       1199  False            False
# 5        <NA>        360       2029   True            False
# 6        <NA>        360       1556   True            False
# 7        <NA>        360       1571   True            False
# 8        <NA>       <NA>       <NA>  False             True
# 9        <NA>        360       2598   True            False
# 10       <NA>        360       3163   True            False
# 11       <NA>        360        882   True            False
# 12       <NA>        360       1610   True            False
# 13       <NA>       <NA>       <NA>  False             True
# 14       <NA>        360       2257   True            False
# 15       <NA>        360       1674   True            False
# 16       <NA>        360       1270   True            False
# 17       <NA>        360       2684   True            False
# 18       <NA>        360       1433   True            False
# 19       <NA>        360       2147   True            False
# 20       <NA>        360       2285   True            False
# 21       <NA>        360        980   True            False
# 22        293        103       1420  False            False
# 23       <NA>        360       2547   True            False
# 24       <NA>        360       1366   True            False
# 25       <NA>        360       2216   True            False
# 26       <NA>        360       1774   True            False
# 27       <NA>        360       1941   True            False
# 28       <NA>        360       2625   True            False
# 29       <NA>        360       1913   True            False
# 30       <NA>        360       1850   True            False
# 31        309        190       1099  False            False
# 32        304         65        827  False            False
# 33       <NA>        360        715   True            False
# 34         98         91        441  False            False
# 35       <NA>        360       2402   True            False
# 36       <NA>        360       2861   True            False
# 37       <NA>        360       3387   True            False
# 38       <NA>        360       1119   True            False
# 39       <NA>        360       1245   True            False
# 40       <NA>        360       2411   True            False
# 41       <NA>        360        669   True            False
# 42       <NA>        360        785   True            False
# 43       <NA>        360       1893   True            False
# 44       <NA>        360        575   True            False
# 45       <NA>        360       1081   True            False
# 46       <NA>        360       1289   True            False
# 47       <NA>        360       1184   True            False
# 48       <NA>        360       1759   True            False
# 49       <NA>        360       2094   True            False
# 50       <NA>        360        671   True            False

# %% [markdown]
# Question 2:
#
# Code Description: The similarity function first determines type of the input and thus determine the type of the data. This function then calls one of the three helper functions: cat_flare_similarity(1 if the same, else 0), num_flare_similarity(used for flare_classification, first compare the first level; if the first letter is the same then use exp(-d) to calculate similarity), dat_flare_similarity(convert date difference into seconds and then apply exp(-d) to calculate similarity).
# For determining the best matching entitiy, I use flare_match function which for each entity in top50 table applies the flare_similarity function to get the entity with the max sum of similarity in NASA table.

# %%
def  cat_flare_similarity(e1, e2):
    return 1 if e1 == e2 else 0

def  num_flare_similarity(e1, e2):
    if e1[0] != e2[0]: 
        return 0
    v1 = float(e1[1:].replace('+', ''))
    v2 = float(e2[1:].replace('+', ''))
    return exp(-(v1-v2)**2)

def  dat_flare_similarity(e1, e2):
    return exp(-((e1-e2).total_seconds())**2)

# %%
def flare_similarity(e1, e2):
    if type(e1) is pd._libs.missing.NAType or type(e2) is pd._libs.missing.NAType: return 0
    if type(e2) is str:
        return cat_flare_similarity(e1,e2)
    else:
        return dat_flare_similarity(e1,e2)

# %%
def flare_match(E1, E2):
    res = [-1]*len(E1.index)
    for i in E1.index:
        maxsim = 0;
        matchindex = ''
        for j in E2.index:
            cur = 0;
            for column in E1: 
                if (column == 'flare_classification'):
                    if not type(E1[column][i]) is pd._libs.missing.NAType and not type(E2[column][j]) is pd._libs.missing.NAType:
                        cur += num_flare_similarity(E1[column][i], E2[column][j])
                else:
                    cur += flare_similarity(E1[column][i], E2[column][j])
            if(cur > maxsim):
                maxsim = cur
                matchindex = j
        if maxsim != 0: 
            res[i-1] = matchindex  
    return res

# %%
test_df = df.drop(columns={'rank'})
test_df = test_df.rename(columns={'max_datetime': 'cme_datetime'})
test_nasa = nasa

# %%
matched = flare_match(test_df, test_nasa)

# %%
df['flare_match'] = matched

# %%
df
# Out:
#     rank flare_classification  flare_region      start_datetime  \
# 1      1                 X28+           486 2003-11-04 19:29:00
# 2      2                 X20+          9393 2001-04-02 21:32:00
# 3      3               X17.2+           486 2003-10-28 09:51:00
# 4      4                 X17+           808 2005-09-07 17:17:00
# 5      5                X14.4          9415 2001-04-15 13:19:00
# 6      6                  X10           486 2003-10-29 20:37:00
# 7      7                 X9.4          8100 1997-11-06 11:49:00
# 8      8                 X9.3          2673 2017-09-06 11:53:00
# 9      9                   X9           930 2006-12-05 10:18:00
# 10    10                 X8.3           486 2003-11-02 17:03:00
# 11    11                 X8.2          2673 2017-09-10 15:35:00
# 12    12                 X7.1           720 2005-01-20 06:36:00
# 13    13                 X6.9          1263 2011-08-09 07:48:00
# 14    14                 X6.5           930 2006-12-06 18:29:00
# 15    15                 X6.2           808 2005-09-09 19:13:00
# 16    16                 X6.2          9733 2001-12-13 14:20:00
# 17    17                 X5.7          9077 2000-07-14 10:03:00
# 18    18                 X5.6          9415 2001-04-06 19:10:00
# 19    19                 X5.4          1429 2012-03-07 00:02:00
# 20    20                 X5.4           808 2005-09-08 20:52:00
# 21    21                 X5.4           486 2003-10-23 08:19:00
# 23 2014-02-25 00:49:00 2014-02-25 01:03:00          444
# 24 1998-08-18 22:19:00 1998-08-18 22:28:00          444
# 25 2002-07-23 00:35:00 2002-07-23 00:47:00          194
# 26 2000-11-26 16:48:00 2000-11-26 16:56:00          105
# 27 2003-11-03 09:55:00 2003-11-03 10:19:00          239
# 28 1998-08-19 21:45:00 1998-08-19 21:50:00          239
# 29 2005-01-17 09:52:00 2005-01-17 10:07:00          287
# 30 1998-11-22 06:42:00 1998-11-22 06:49:00          287
# 31 2005-09-09 09:59:00 2005-09-09 10:08:00          223
# 32 2004-07-16 13:55:00 2004-07-16 14:01:00          223
# 33 2003-05-28 00:27:00 2003-05-28 00:39:00          223
# 34 2006-12-13 02:40:00 2006-12-13 02:57:00          161
# 35 2001-12-28 20:45:00 2001-12-28 21:32:00          161
# 36 2013-11-05 22:12:00 2013-11-05 22:15:00          193
# 37 2002-07-20 21:30:00 2002-07-20 21:54:00          193
# 38 1998-11-28 05:52:00 1998-11-28 06:13:00          193
# 39 2013-05-14 01:11:00 2013-05-14 01:20:00          405
# 40 2014-10-24 21:41:00 2014-10-24 22:13:00          202
# 41 2002-08-24 01:12:00 2002-08-24 01:31:00          202
# 42 2002-07-15 20:08:00 2002-07-15 20:14:00          202
# 43 2013-05-13 16:05:00 2013-05-13 16:16:00          404
# 44 2001-12-11 08:08:00 2001-12-11 08:14:00          404
# 45 1998-08-18 08:24:00 1998-08-18 08:32:00          404
# 46 2015-05-05 22:11:00 2015-05-05 22:15:00           20
# 47 2003-11-03 01:30:00 2003-11-03 01:45:00           20
# 48 1998-05-06 08:09:00 1998-05-06 08:20:00           20
# 49 2005-01-15 23:02:00 2005-01-15 23:31:00           10
# 50 2001-09-24 10:38:00 2001-09-24 11:09:00           10

# %% [markdown]
# Question 3:
#
# Description:
#
# a. The intent of the plot is to show the end_frequencies of the top50 flares compared to the other flares in the NASA table over start time. We want to observe the variation, spread, skew of the top50 points compared to the rest of the points to see if they show some specific pattern in order to determine if the top50 flares has any end_frequency pattern.
#
# c.The plot uses the dataframe of nasa. It maps start_datetime to x-axis and end_frequency to y-axis. It's geometry is point. And top50 points are blue while others are red.
#
# d. In my plot, the top50 points and the other points demonstrate relatively the same spread along the start_datetime(there is a gap between 2008 mid year and 2010 January.) But the top50 points have relatively low variance at the end_frequency of 0~100 compared to the other points. The distribution of top50 points' end-frequency is left-skewed and the center is close to around 100.

# %%
comp = nasa

# %%
newcol = []

# %%
for i in comp.index:
    if i in df.flare_match.tolist():
        newcol.append(True)
    else:
        newcol.append(False)

# %%
comp['top50'] = newcol

# %%
from plotnine import *
(ggplot(comp[['start_datetime', 'end_frequency', 'top50']].dropna(), aes(x='start_datetime', y='end_frequency', color = 'top50')) + geom_point())
# Out:
# C:\Users\jason\Anaconda3\lib\site-packages\plotnine\scales\scale.py:93: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cbook.iterable(self.breaks) and cbook.iterable(self.labels):
# C:\Users\jason\Anaconda3\lib\site-packages\plotnine\utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# C:\Users\jason\Anaconda3\lib\site-packages\plotnine\utils.py:553: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   return cbook.iterable(var) and not is_string(var)
# <ggplot: (166748127096)>
